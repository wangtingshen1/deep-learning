# %%
import keras
from keras import models
from keras import layers
from keras.applications.nasnet import NASNetLarge
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout,Flatten
from keras.layers import Conv2D,MaxPool2D
from keras.utils import plot_model


# 定义输入
input_shape = (224,224,3) # RGB影像224x224（height,width,channel)
#引用模型
conv_base = NASNetLarge(weights=None, include_top=False, pooling='avg',input_shape=input_shape)
conv_base.summary()
# Out:
# Model: "NASNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# stem_conv1 (Conv2D)             (None, 111, 111, 96) 2592        input_2[0][0]
# __________________________________________________________________________________________________
# stem_bn1 (BatchNormalization)   (None, 111, 111, 96) 384         stem_conv1[0][0]
# __________________________________________________________________________________________________
# activation_261 (Activation)     (None, 111, 111, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_1 (Conv2D (None, 111, 111, 42) 4032        activation_261[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_1 (BatchNor (None, 111, 111, 42) 168         reduction_conv_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_262 (Activation)     (None, 111, 111, 42) 0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_264 (Activation)     (None, 111, 111, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 115, 115, 42) 0           activation_262[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 117, 117, 96) 0           activation_264[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 56, 56, 42)   2814        separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 56, 56, 42)   8736        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 56, 56, 42)   168         separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 56, 56, 42)   168         separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_263 (Activation)     (None, 56, 56, 42)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_265 (Activation)     (None, 56, 56, 42)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 56, 56, 42)   2814        activation_263[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 56, 56, 42)   3822        activation_265[0][0]
# __________________________________________________________________________________________________
# activation_266 (Activation)     (None, 111, 111, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 56, 56, 42)   168         separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 56, 56, 42)   168         separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 117, 117, 96) 0           activation_266[0][0]
# __________________________________________________________________________________________________
# activation_268 (Activation)     (None, 111, 111, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_1 (Add)    (None, 56, 56, 42)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 56, 56, 42)   8736        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 115, 115, 96) 0           activation_268[0][0]
# __________________________________________________________________________________________________
# activation_270 (Activation)     (None, 56, 56, 42)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 56, 56, 42)   168         separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 56, 56, 42)   6432        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 56, 56, 42)   2142        activation_270[0][0]
# __________________________________________________________________________________________________
# activation_267 (Activation)     (None, 56, 56, 42)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 56, 56, 42)   168         separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 56, 56, 42)   168         separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_1 (ZeroPad (None, 113, 113, 42) 0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 56, 56, 42)   3822        activation_267[0][0]
# __________________________________________________________________________________________________
# activation_269 (Activation)     (None, 56, 56, 42)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_271 (Activation)     (None, 56, 56, 42)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_1 (MaxPool (None, 56, 56, 42)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 56, 56, 42)   168         separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 56, 56, 42)   2814        activation_269[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 56, 56, 42)   2142        activation_271[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_stem_2 (Activatio (None, 111, 111, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_1 (Add)    (None, 56, 56, 42)   0           reduction_left2_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_1 (Average (None, 56, 56, 42)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 56, 56, 42)   168         separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_1 (Average (None, 56, 56, 42)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 56, 56, 42)   168         separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_1 (MaxPoo (None, 56, 56, 42)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 112, 112, 96) 0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_1 (Add)     (None, 56, 56, 42)   0           reduction_left3_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 56, 56, 42)   0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_left4_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_1 (Add)     (None, 56, 56, 42)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_1[0][0]
# __________________________________________________________________________________________________
# cropping2d_5 (Cropping2D)       (None, 111, 111, 96) 0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_1 (Concat (None, 56, 56, 168)  0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_add3_stem_1[0][0]
#                                                                  add_5[0][0]
#                                                                  reduction_add4_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_stem_2 (Avera (None, 56, 56, 96)   0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_stem_2 (Avera (None, 56, 56, 96)   0           cropping2d_5[0][0]
# __________________________________________________________________________________________________
# activation_272 (Activation)     (None, 56, 56, 168)  0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_stem_2 (Conv2D)   (None, 56, 56, 42)   4032        adjust_avg_pool_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_stem_2 (Conv2D)   (None, 56, 56, 42)   4032        adjust_avg_pool_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_2 (Conv2D (None, 56, 56, 84)   14112       activation_272[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 56, 56, 84)   0           adjust_conv_1_stem_2[0][0]
#                                                                  adjust_conv_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_2 (BatchNor (None, 56, 56, 84)   336         reduction_conv_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_bn_stem_2 (BatchNormaliz (None, 56, 56, 84)   336         concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_273 (Activation)     (None, 56, 56, 84)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# activation_275 (Activation)     (None, 56, 56, 84)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 59, 59, 84)   0           activation_273[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 61, 61, 84)   0           activation_275[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 28, 28, 84)   9156        separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 28, 28, 84)   11172       separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 28, 28, 84)   336         separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 28, 28, 84)   336         separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_274 (Activation)     (None, 28, 28, 84)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_276 (Activation)     (None, 28, 28, 84)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 28, 28, 84)   9156        activation_274[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 28, 28, 84)   11172       activation_276[0][0]
# __________________________________________________________________________________________________
# activation_277 (Activation)     (None, 56, 56, 84)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 28, 28, 84)   336         separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 28, 28, 84)   336         separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 61, 61, 84)   0           activation_277[0][0]
# __________________________________________________________________________________________________
# activation_279 (Activation)     (None, 56, 56, 84)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_2 (Add)    (None, 28, 28, 84)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 28, 28, 84)   11172       separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 59, 59, 84)   0           activation_279[0][0]
# __________________________________________________________________________________________________
# activation_281 (Activation)     (None, 28, 28, 84)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 28, 28, 84)   336         separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 28, 28, 84)   9156        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 28, 28, 84)   7812        activation_281[0][0]
# __________________________________________________________________________________________________
# activation_278 (Activation)     (None, 28, 28, 84)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 28, 28, 84)   336         separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 28, 28, 84)   336         separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_2 (ZeroPad (None, 57, 57, 84)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 28, 28, 84)   11172       activation_278[0][0]
# __________________________________________________________________________________________________
# activation_280 (Activation)     (None, 28, 28, 84)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_282 (Activation)     (None, 28, 28, 84)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_2 (MaxPool (None, 28, 28, 84)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 28, 28, 84)   336         separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 28, 28, 84)   9156        activation_280[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 28, 28, 84)   7812        activation_282[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_0 (Activation)    (None, 56, 56, 168)  0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_2 (Add)    (None, 28, 28, 84)   0           reduction_left2_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_2 (Average (None, 28, 28, 84)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 28, 28, 84)   336         separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_2 (Average (None, 28, 28, 84)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 28, 28, 84)   336         separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_2 (MaxPoo (None, 28, 28, 84)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 57, 57, 168)  0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_2 (Add)     (None, 28, 28, 84)   0           reduction_left3_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 28, 28, 84)   0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_left4_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_2 (Add)     (None, 28, 28, 84)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_2[0][0]
# __________________________________________________________________________________________________
# cropping2d_6 (Cropping2D)       (None, 56, 56, 168)  0           zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_2 (Concat (None, 28, 28, 336)  0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_add3_stem_2[0][0]
#                                                                  add_6[0][0]
#                                                                  reduction_add4_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_0 (AveragePoo (None, 28, 28, 168)  0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_0 (AveragePoo (None, 28, 28, 168)  0           cropping2d_6[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_0 (Conv2D)        (None, 28, 28, 84)   14112       adjust_avg_pool_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_0 (Conv2D)        (None, 28, 28, 84)   14112       adjust_avg_pool_2_0[0][0]
# __________________________________________________________________________________________________
# activation_283 (Activation)     (None, 28, 28, 336)  0           reduction_concat_stem_2[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 28, 28, 168)  0           adjust_conv_1_0[0][0]
#                                                                  adjust_conv_2_0[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_0 (Conv2D)        (None, 28, 28, 168)  56448       activation_283[0][0]
# __________________________________________________________________________________________________
# adjust_bn_0 (BatchNormalization (None, 28, 28, 168)  672         concatenate_6[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_0 (BatchNormalizati (None, 28, 28, 168)  672         normal_conv_1_0[0][0]
# __________________________________________________________________________________________________
# activation_284 (Activation)     (None, 28, 28, 168)  0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# activation_286 (Activation)     (None, 28, 28, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_288 (Activation)     (None, 28, 28, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_290 (Activation)     (None, 28, 28, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_292 (Activation)     (None, 28, 28, 168)  0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_0 (None, 28, 28, 168)  32424       activation_284[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 28, 28, 168)  29736       activation_286[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_0 (None, 28, 28, 168)  32424       activation_288[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 28, 28, 168)  29736       activation_290[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_0 (None, 28, 28, 168)  29736       activation_292[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 168)  672         separable_conv_1_normal_left1_0[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_1_normal_right1_0[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 168)  672         separable_conv_1_normal_left2_0[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_1_normal_right2_0[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 168)  672         separable_conv_1_normal_left5_0[0
# __________________________________________________________________________________________________
# activation_285 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_287 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_289 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_291 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_293 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_0 (None, 28, 28, 168)  32424       activation_285[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 28, 28, 168)  29736       activation_287[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_0 (None, 28, 28, 168)  32424       activation_289[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 28, 28, 168)  29736       activation_291[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_0 (None, 28, 28, 168)  29736       activation_293[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 168)  672         separable_conv_2_normal_left1_0[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_2_normal_right1_0[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 168)  672         separable_conv_2_normal_left2_0[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_2_normal_right2_0[
# __________________________________________________________________________________________________
# normal_left3_0 (AveragePooling2 (None, 28, 28, 168)  0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# normal_left4_0 (AveragePooling2 (None, 28, 28, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# normal_right4_0 (AveragePooling (None, 28, 28, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 168)  672         separable_conv_2_normal_left5_0[0
# __________________________________________________________________________________________________
# normal_add_1_0 (Add)            (None, 28, 28, 168)  0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_0 (Add)            (None, 28, 28, 168)  0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_0 (Add)            (None, 28, 28, 168)  0           normal_left3_0[0][0]
#                                                                  adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# normal_add_4_0 (Add)            (None, 28, 28, 168)  0           normal_left4_0[0][0]
#                                                                  normal_right4_0[0][0]
# __________________________________________________________________________________________________
# normal_add_5_0 (Add)            (None, 28, 28, 168)  0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# normal_concat_0 (Concatenate)   (None, 28, 28, 1008) 0           adjust_bn_0[0][0]
#                                                                  normal_add_1_0[0][0]
#                                                                  normal_add_2_0[0][0]
#                                                                  normal_add_3_0[0][0]
#                                                                  normal_add_4_0[0][0]
#                                                                  normal_add_5_0[0][0]
# __________________________________________________________________________________________________
# activation_294 (Activation)     (None, 28, 28, 336)  0           reduction_concat_stem_2[0][0]
# __________________________________________________________________________________________________
# activation_295 (Activation)     (None, 28, 28, 1008) 0           normal_concat_0[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_1 (Conv2 (None, 28, 28, 168)  56448       activation_294[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_1 (Conv2D)        (None, 28, 28, 168)  169344      activation_295[0][0]
# __________________________________________________________________________________________________
# adjust_bn_1 (BatchNormalization (None, 28, 28, 168)  672         adjust_conv_projection_1[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_1 (BatchNormalizati (None, 28, 28, 168)  672         normal_conv_1_1[0][0]
# __________________________________________________________________________________________________
# activation_296 (Activation)     (None, 28, 28, 168)  0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# activation_298 (Activation)     (None, 28, 28, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_300 (Activation)     (None, 28, 28, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_302 (Activation)     (None, 28, 28, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_304 (Activation)     (None, 28, 28, 168)  0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_1 (None, 28, 28, 168)  32424       activation_296[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 28, 28, 168)  29736       activation_298[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_1 (None, 28, 28, 168)  32424       activation_300[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 28, 28, 168)  29736       activation_302[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_1 (None, 28, 28, 168)  29736       activation_304[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 168)  672         separable_conv_1_normal_left1_1[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_1_normal_right1_1[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 168)  672         separable_conv_1_normal_left2_1[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_1_normal_right2_1[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 168)  672         separable_conv_1_normal_left5_1[0
# __________________________________________________________________________________________________
# activation_297 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_299 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_301 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_303 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_305 (Activation)     (None, 28, 28, 168)  0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 28, 28, 168)  32424       activation_297[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 28, 28, 168)  29736       activation_299[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 28, 28, 168)  32424       activation_301[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 28, 28, 168)  29736       activation_303[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 28, 28, 168)  29736       activation_305[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 168)  672         separable_conv_2_normal_left1_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_2_normal_right1_1[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 168)  672         separable_conv_2_normal_left2_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_2_normal_right2_1[
# __________________________________________________________________________________________________
# normal_left3_1 (AveragePooling2 (None, 28, 28, 168)  0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_left4_1 (AveragePooling2 (None, 28, 28, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_right4_1 (AveragePooling (None, 28, 28, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 168)  672         separable_conv_2_normal_left5_1[0
# __________________________________________________________________________________________________
# normal_add_1_1 (Add)            (None, 28, 28, 168)  0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_1 (Add)            (None, 28, 28, 168)  0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_1 (Add)            (None, 28, 28, 168)  0           normal_left3_1[0][0]
#                                                                  adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_add_4_1 (Add)            (None, 28, 28, 168)  0           normal_left4_1[0][0]
#                                                                  normal_right4_1[0][0]
# __________________________________________________________________________________________________
# normal_add_5_1 (Add)            (None, 28, 28, 168)  0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_concat_1 (Concatenate)   (None, 28, 28, 1008) 0           adjust_bn_1[0][0]
#                                                                  normal_add_1_1[0][0]
#                                                                  normal_add_2_1[0][0]
#                                                                  normal_add_3_1[0][0]
#                                                                  normal_add_4_1[0][0]
#                                                                  normal_add_5_1[0][0]
# __________________________________________________________________________________________________
# activation_306 (Activation)     (None, 28, 28, 1008) 0           normal_concat_0[0][0]
# __________________________________________________________________________________________________
# activation_307 (Activation)     (None, 28, 28, 1008) 0           normal_concat_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_2 (Conv2 (None, 28, 28, 168)  169344      activation_306[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_2 (Conv2D)        (None, 28, 28, 168)  169344      activation_307[0][0]
# __________________________________________________________________________________________________
# adjust_bn_2 (BatchNormalization (None, 28, 28, 168)  672         adjust_conv_projection_2[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_2 (BatchNormalizati (None, 28, 28, 168)  672         normal_conv_1_2[0][0]
# __________________________________________________________________________________________________
# activation_308 (Activation)     (None, 28, 28, 168)  0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# activation_310 (Activation)     (None, 28, 28, 168)  0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_312 (Activation)     (None, 28, 28, 168)  0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_314 (Activation)     (None, 28, 28, 168)  0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_316 (Activation)     (None, 28, 28, 168)  0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_2 (None, 28, 28, 168)  32424       activation_308[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 28, 28, 168)  29736       activation_310[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_2 (None, 28, 28, 168)  32424       activation_312[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 28, 28, 168)  29736       activation_314[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_2 (None, 28, 28, 168)  29736       activation_316[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 168)  672         separable_conv_1_normal_left1_2[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 168)  672         separable_conv_1_normal_right1_2[
# ...
# __________________________________________________________________________________________________
# activation_503 (Activation)     (None, 7, 7, 672)    0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_505 (Activation)     (None, 7, 7, 672)    0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_507 (Activation)     (None, 7, 7, 672)    0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 7, 7, 672)    468384      activation_499[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 7, 7, 672)    457632      activation_501[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 7, 7, 672)    468384      activation_503[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 7, 7, 672)    457632      activation_505[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 7, 7, 672)    457632      activation_507[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_2_normal_left1_17[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 672)    2688        separable_conv_2_normal_right1_17
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_2_normal_left2_17[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 672)    2688        separable_conv_2_normal_right2_17
# __________________________________________________________________________________________________
# normal_left3_17 (AveragePooling (None, 7, 7, 672)    0           normal_bn_1_17[0][0]
# __________________________________________________________________________________________________
# normal_left4_17 (AveragePooling (None, 7, 7, 672)    0           adjust_bn_17[0][0]
# __________________________________________________________________________________________________
# normal_right4_17 (AveragePoolin (None, 7, 7, 672)    0           adjust_bn_17[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_2_normal_left5_17[
# __________________________________________________________________________________________________
# normal_add_1_17 (Add)           (None, 7, 7, 672)    0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_17 (Add)           (None, 7, 7, 672)    0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_17 (Add)           (None, 7, 7, 672)    0           normal_left3_17[0][0]
#                                                                  adjust_bn_17[0][0]
# __________________________________________________________________________________________________
# normal_add_4_17 (Add)           (None, 7, 7, 672)    0           normal_left4_17[0][0]
#                                                                  normal_right4_17[0][0]
# __________________________________________________________________________________________________
# normal_add_5_17 (Add)           (None, 7, 7, 672)    0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_17[0][0]
# __________________________________________________________________________________________________
# normal_concat_17 (Concatenate)  (None, 7, 7, 4032)   0           adjust_bn_17[0][0]
#                                                                  normal_add_1_17[0][0]
#                                                                  normal_add_2_17[0][0]
#                                                                  normal_add_3_17[0][0]
#                                                                  normal_add_4_17[0][0]
#                                                                  normal_add_5_17[0][0]
# __________________________________________________________________________________________________
# activation_508 (Activation)     (None, 7, 7, 4032)   0           normal_concat_16[0][0]
# __________________________________________________________________________________________________
# activation_509 (Activation)     (None, 7, 7, 4032)   0           normal_concat_17[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_18 (Conv (None, 7, 7, 672)    2709504     activation_508[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_18 (Conv2D)       (None, 7, 7, 672)    2709504     activation_509[0][0]
# __________________________________________________________________________________________________
# adjust_bn_18 (BatchNormalizatio (None, 7, 7, 672)    2688        adjust_conv_projection_18[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_18 (BatchNormalizat (None, 7, 7, 672)    2688        normal_conv_1_18[0][0]
# __________________________________________________________________________________________________
# activation_510 (Activation)     (None, 7, 7, 672)    0           normal_bn_1_18[0][0]
# __________________________________________________________________________________________________
# activation_512 (Activation)     (None, 7, 7, 672)    0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# activation_514 (Activation)     (None, 7, 7, 672)    0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# activation_516 (Activation)     (None, 7, 7, 672)    0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# activation_518 (Activation)     (None, 7, 7, 672)    0           normal_bn_1_18[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_1 (None, 7, 7, 672)    468384      activation_510[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 7, 7, 672)    457632      activation_512[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_1 (None, 7, 7, 672)    468384      activation_514[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 7, 7, 672)    457632      activation_516[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_1 (None, 7, 7, 672)    457632      activation_518[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_1_normal_left1_18[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 7, 7, 672)    2688        separable_conv_1_normal_right1_18
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_1_normal_left2_18[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 7, 7, 672)    2688        separable_conv_1_normal_right2_18
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_1_normal_left5_18[
# __________________________________________________________________________________________________
# activation_511 (Activation)     (None, 7, 7, 672)    0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_513 (Activation)     (None, 7, 7, 672)    0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_515 (Activation)     (None, 7, 7, 672)    0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_517 (Activation)     (None, 7, 7, 672)    0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_519 (Activation)     (None, 7, 7, 672)    0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 7, 7, 672)    468384      activation_511[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 7, 7, 672)    457632      activation_513[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 7, 7, 672)    468384      activation_515[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 7, 7, 672)    457632      activation_517[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 7, 7, 672)    457632      activation_519[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_2_normal_left1_18[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 672)    2688        separable_conv_2_normal_right1_18
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_2_normal_left2_18[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 672)    2688        separable_conv_2_normal_right2_18
# __________________________________________________________________________________________________
# normal_left3_18 (AveragePooling (None, 7, 7, 672)    0           normal_bn_1_18[0][0]
# __________________________________________________________________________________________________
# normal_left4_18 (AveragePooling (None, 7, 7, 672)    0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# normal_right4_18 (AveragePoolin (None, 7, 7, 672)    0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 672)    2688        separable_conv_2_normal_left5_18[
# __________________________________________________________________________________________________
# normal_add_1_18 (Add)           (None, 7, 7, 672)    0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_18 (Add)           (None, 7, 7, 672)    0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_18 (Add)           (None, 7, 7, 672)    0           normal_left3_18[0][0]
#                                                                  adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# normal_add_4_18 (Add)           (None, 7, 7, 672)    0           normal_left4_18[0][0]
#                                                                  normal_right4_18[0][0]
# __________________________________________________________________________________________________
# normal_add_5_18 (Add)           (None, 7, 7, 672)    0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_18[0][0]
# __________________________________________________________________________________________________
# normal_concat_18 (Concatenate)  (None, 7, 7, 4032)   0           adjust_bn_18[0][0]
#                                                                  normal_add_1_18[0][0]
#                                                                  normal_add_2_18[0][0]
#                                                                  normal_add_3_18[0][0]
#                                                                  normal_add_4_18[0][0]
#                                                                  normal_add_5_18[0][0]
# __________________________________________________________________________________________________
# activation_520 (Activation)     (None, 7, 7, 4032)   0           normal_concat_18[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 4032)         0           activation_520[0][0]
# ==================================================================================================
# Total params: 84,916,818
# Trainable params: 84,720,150
# Non-trainable params: 196,668
# __________________________________________________________________________________________________

# %%
#定义模型
model = models.Sequential()
# 前馈全连接区块
model.add(conv_base)
model.add(Dense(1,activation='sigmoid',name='predictions'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# NASNet (Model)               (None, 4032)              84916818
# _________________________________________________________________
# predictions (Dense)          (None, 1)                 4033
# =================================================================
# Total params: 84,920,851
# Trainable params: 84,724,183
# Non-trainable params: 196,668
# _________________________________________________________________
